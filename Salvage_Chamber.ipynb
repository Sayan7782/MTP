# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=[154,148,150,126,123]
y=[20,16,17,14,11]

# %%
mymodel = np.poly1d(np.polyfit(x, y, 1))

myline = np.linspace(120, 155, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.xlabel("Face length(in m)")
plt.ylabel("Formation of Salvage Chamber(in days)")
plt.show()

# %%
from sklearn.metrics import r2_score
print(r2_score(y, mymodel(x)))
# Out:
# 0.8428543594127111

# %%
print(mymodel.coeffs)
# Out:
# [  0.21235795 -14.17258523]
