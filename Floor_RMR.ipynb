# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=[32.17,39.92,38.14,33.68,42.70,27.32,44.67,38.42]
y=[5.52,6.05,4.79,4.62,5.43,4.86,5.81,5.12]

# %%
mymodel = np.poly1d(np.polyfit(x, y, 4))

myline = np.linspace(25,50,100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.xlabel("Face Length(in m) ")
plt.ylabel("Face Advance Rate Actual(m/d)")
plt.show()

# %%
from sklearn.metrics import r2_score
print(r2_score(y, mymodel(x)))
# Out:
# 0.48221164008224193

# %%
print(mymodel.coeffs)
# Out:
# [-4.24365972e-04  6.14151328e-02 -3.29535791e+00  7.77013750e+01
#  -6.74236608e+02]
