# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=[2.7,9.1,12.5,13.2,18.4,12.6,7.8,4.8]
y=[5.52,6.05,4.79,4.62,5.43,4.86,5.81,5.12]

# %%
mymodel = np.poly1d(np.polyfit(x, y, 3))

myline = np.linspace(1, 20,20)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.xlabel("Gas Propagation (m^3/t)")
plt.ylabel("Face Advance Rate Actual(m/d)")
plt.show()

# %%
from sklearn.metrics import r2_score
print(r2_score(y, mymodel(x)))
# Out:
# 0.5431546448800457

# %%
print(mymodel.coeffs)
# Out:
# [ 3.23834117e-03 -1.01606991e-01  8.72177441e-01  3.55402446e+00]
